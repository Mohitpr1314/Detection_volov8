# %%
# !nvidia-smi
# Out:
# Sun Sep 22 12:08:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !git clone https://github.com/Mohitpr1314/Car-dataset-for-segmentation.git
# Out:
# Cloning into 'Car-dataset-for-segmentation'...
# remote: Enumerating objects: 3097, done.
# remote: Total 3097 (delta 0), reused 0 (delta 0), pack-reused 3097 (from 1)
# Receiving objects: 100% (3097/3097), 309.95 MiB | 16.27 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# Updating files: 100% (3082/3082), done.

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.2/112.6 GB disk)

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
model.train(data='/content/Car-dataset-for-segmentation/Car/data.yaml', epochs=25, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 248MB/s]
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content
# Out:
# /content

# %%
model.val()
# Out:
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/Car-dataset-for-segmentation/Car/valid/labels.cache... 31 images, 1 backgrounds, 0 corrupt: 100%|██████████| 31/31 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.86it/s]
#                    all         31        339       0.53      0.558      0.496       0.27
#                   bike          7         13      0.348      0.385      0.245      0.104
#                    bus         14         22       0.37      0.453       0.42      0.318
#                    car         30        289       0.53      0.792      0.674      0.417
# ...

# %%
model.predict(source='/853908-hd_1920_1080_25fps.mp4', save=True, )
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/362) /853908-hd_1920_1080_25fps.mp4: 384x640 2 cars, 55.3ms
# video 1/1 (frame 2/362) /853908-hd_1920_1080_25fps.mp4: 384x640 1 bike, 3 cars, 10.0ms
# video 1/1 (frame 3/362) /853908-hd_1920_1080_25fps.mp4: 384x640 1 bike, 3 cars, 9.0ms
# video 1/1 (frame 4/362) /853908-hd_1920_1080_25fps.mp4: 384x640 3 cars, 9.1ms
# video 1/1 (frame 5/362) /853908-hd_1920_1080_25fps.mp4: 384x640 2 cars, 11.4ms
# ...
